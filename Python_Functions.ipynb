# %% [markdown]
# **PYTHON FUNCTIONS:**
# * A function is a block of code that performs a specific task
# * We can pass data known a s parameters into a function.
# * A function can return data as a result.
# * A top-to-down approach towards building the processing logic involves defining blocks of independent reusable functions.
# * A Python function may be invoked from any other function by passing required data (called parameters or arguments).
# * The called function returns its result back to the calling environment.
#
# **SYNTAX:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Examples:**

# %%
# A simple Python function
def fun():
    print("Welcome to Python")

# %% [markdown]
# **TYPES OF PYTHON FUNCTIONS:**
# * Python provides the following types of functions:
#
# **1)Built-in Functions:**
# * Built-in functions are those functions that are pre-defined in the Python interpreter and you don't need to import any module to use them.
# * These functions help to perform a wide variety of operations on strings, iterators, and numbers.
# * For instance, the built-in functions like sum(), min(), and max() are used to simplify mathematical operations.
# * To use built-in functions in your code, simply call the specific function by passing the required parameter (if any) inside the parentheses.
# * Since these functions are pre-defined, you don't need to import any module or package.
#
# **Examples:**

# %%
# Using print() and len() function
text = "Revanth"
print(len(text))
# Out:
# 7

# %% [markdown]
# **2)Python Built-in Modules:**
# * The standard library also bundles a number of modules.
# * Each module defines a group of functions. These functions are not readily available.
# * We need to import them into the memory from their respective modules.
#
# **Examples:**

# %%
import math
print ("Square root of 100:", math.sqrt(100))
# Out:
# Square root of 100: 10.0

# %% [markdown]
# **3)User-defined functions:**
# * In addition to the built-in functions and functions in the built-in modules, we can also create your own functions based on our requirements.
# * These functions are called user-defined functions.
#
# **Examples:**

# %%
def add(a, b):
    return a + b
result = add(5, 3)
print(result)
# Out:
# 8

# %% [markdown]
# **Calling a Function in python:**
# * After creating a function in Python we can call it by using the name of the functions Python followed by parenthesis containing parameters of that particular function.
# * Defining a function only gives it a name, specifies the parameters that are to be included in the function and structures the blocks of code.
# * Once the basic structure of a function is finalized, you can call it by using the function name itself.
# * If the function requires any parameters, they should be passed within parentheses.
# * If the function doesn't require any parameters, the parentheses should be left empty.
#
# **Examples:**

# %%
# A simple Python function
def fun():
    print("Welcome to data science")
# Driver code to call a function
fun()
# Out:
# Welcome to data science

# %%
# Function definition is here
def printme( str ):
   "This prints a passed string into this function"
   print (str)
   return;

# Now you can call the function
printme("I'm first call to user defined function!")
printme("Again second call to the same function")
# Out:
# I'm first call to user defined function!
# Again second call to the same function

# %% [markdown]
# **Python Fumction Arguments:**
# * Information can be passed into functions as arguments.
# * Arguments are specified after the function name, inside the parentheses.
# * We can add as many arguments as you want, just separate them with a comma.
# * While defining a function, you specify a list of variables (known as formal parameters) within the parentheses.
# * These parameters act as placeholders for the data that will be passed to the function when it is called.
# * When the function is called, value to each of the formal arguments must be provided. Those are called actual arguments.

# %% [markdown]
# **SYNTAX:**
#
# ![image.png](data:image/png;base64,...)

# %%
def my_function(fname):
  print(fname + "Reddy")

my_function("Revanth")
my_function("Jashwanth")
my_function("Rahul")
# Out:
# RevanthReddy
# JashwanthReddy
# RahulReddy

# %%
def greetings(name):
   "This is docstring of greetings function"
   print ("Hello {}".format(name))
   return

greetings("Sai kumar")
greetings("Kiran raj")
greetings("Revanth")
# Out:
# Hello Sai kumar
# Hello Kiran raj
# Hello Revanth

# %% [markdown]
# **Types of Python Function Arguments:**
# * Python supports various types of arguments that can be passed at the time of the function call.
# * In Python, we have the following function argument types in Python:
#
#  1)Default argument
#
#  2)Keyword arguments (named arguments)
#
#  3)Positional arguments
#
#  4)Arbitrary arguments (variable-length arguments *args and **kwargs)

# %% [markdown]
# **1)Default argument:**
#
#  A default argument is a parameter that assumes a default value if a value is not provided in the function call for that argument.
#
# **Examples:**

# %%
# Python program to demonstrate
# default arguments
def myFun(x, y=50):
    print("x: ", x)
    print("y: ", y)
# Driver code (We call myFun() with only
# argument)
myFun(10)
# Out:
# x:  10
# y:  50

# %% [markdown]
# **2)Keyword arguments:**
#
# The idea is to allow the caller to specify the argument name with values so that the caller does not need to remember the order of parameters.
#
# **Examples:**

# %%
# Python program to demonstrate Keyword Arguments
def student(firstname, lastname):
    print(firstname, lastname)
# Keyword arguments
student(firstname='Revanth', lastname='Reddy')
student(lastname='Reddy', firstname='Revanth')
# Out:
# Revanth Reddy
# Revanth Reddy

# %% [markdown]
# **3)Positional arguments:**
# * We use the Position argument during the function call so that the first argument (or value) is assigned to name and the second argument (or value) is assigned to age.
# * By changing the position, or if we forget the order of the positions, the values can be used in the wrong places.
#
# **Examples:**

# %%
def nameAge(name, age):
    print("Hi, I am", name)
    print("My age is ", age)
# You will get correct output because
# argument is given in order
print("Case-1:")
nameAge("Revanth", 21)
# You will get incorrect output because
# argument is not in order
print("\nCase-2:")
nameAge(21, "Revanth")
# Out:
# Case-1:
# Hi, I am Revanth
# My age is  21
#
# Case-2:
# Hi, I am 21
# My age is  Revanth

# %% [markdown]
# **4)Arbitrary arguments:**
# * In Python Arbitrary Keyword Arguments, *args, and **kwargs can pass a variable number of arguments to a function using special symbols. There are two special symbols:
#
#  a) args in Python (Non-Keyword Arguments)
#
#  b) kwargs in Python (Keyword Arguments)
#
# **Examples:**

# %%
# Python program to illustrate
# *args for variable number of arguments
def myFun(*argv):
    for arg in argv:
        print(arg)
myFun('Hello', 'Welcome', 'to', 'Nizamabad')
# Out:
# Hello
# Welcome
# to
# Nizamabad

# %%
# Python program to illustrate
# *kwargs for variable number of keyword arguments
def myFun(**kwargs):
    for key, value in kwargs.items():
        print("%s == %s" % (key, value))
# Driver code
myFun(first='Welcome', mid='to', last='python')
# Out:
# first == Welcome
# mid == to
# last == python

# %% [markdown]
# **return() statement in python:**
# * The function return statement is used to exit from a function and go back to the function caller and return the specified value or data item to the caller.
# * The return keyword as the last statement in function definition indicates end of function block, and the program flow goes back to the calling function.
# * To let a function return a value, use the return statement.
# * The syntax for the return statement is:
#       return [expression_list]
#
# **Examples:**

# %%
def my_function(x):
  return 5 * x

print(my_function(3))
print(my_function(5))
print(my_function(9))
# Out:
# 15
# 25
# 45

# %%
def add(x,y):
   z=x+y
   return z
a=10
b=20
result = add(a,b)
print ("a = {} b = {} a+b = {}".format(a, b, result))
# Out:
# a = 10 b = 20 a+b = 30

# %%
def square_value(num):
    return num**2
print(square_value(2))
print(square_value(-4))
# Out:
# 4
# 16

# %% [markdown]
# **The pass Statement:**
# * The pass statement serves as a placeholder for future code, preventing errors from empty code blocks.
# *It's typically used where code is planned but has yet to be written.
#
# **Examples:**

# %%
def future_function():
    pass

# this will execute without any action or error
future_function()

# %%
def myfunction():
  pass

# %% [markdown]
# **Python Library Functions():**
# * In python,standard library functions are the built-in functions that can be used directly in our program.
# * We don't need to create the function, we just need to call them.
#
#   Print()-prints the string inside the quotation marks.
#
#   sqrt()-returns the square root of a number.
#
#   pow()-returns the power of a number.
# * These library functions are defined inside the module. And to use them, we must include the module inside our program.
#
# **Examples:**

# %%
import math

# sqrt computes the square root
square_root = math.sqrt(4)

print("Square Root of 4 is",square_root)

# pow() comptes the power
power = pow(2, 3)

print("2 to the power 3 is",power)
# Out:
# Square Root of 4 is 2.0
# 2 to the power 3 is 8

# %% [markdown]
# **Python Lambda function():**
# * A lambda function is a small anonymous function.
# * The functions are called anonymous when they are not declared in the standard manner by using the def keyword.
# * Instead, they are defined using the lambda keyword.
# * Lambda forms can take any number of arguments but return just one value in the form of an expression.
# * They cannot contain commands or multiple expressions.
# * An anonymous function cannot be a direct call to print because lambda requires an expression
# * Lambda functions have their own local namespace and cannot access variables other than those in their parameter list and those in the global namespace.
#
# **SYNTAX:**
#
# The syntax of lambda functions contains only a single statement, which is as follows:
#
#         lambda arguments : expression
#
# **Examples:**

# %%
x=lambda a:a+100
print(x(20)) #print(x(a))
# Out:
# 120

# %%
# Function definition is here
sum = lambda arg1, arg2: arg1 + arg2;
print ("Value of total : ", sum( 10, 20 ))
print ("Value of total : ", sum( 20, 20 ))
# Out:
# Value of total :  30
# Value of total :  40

# %%
multiply = lambda x, y: x * y
result = multiply(4, 5)
print(result)
# Out:
# 20

# %% [markdown]
# **Using lambda() Function with filter():**
# * The filter() method accepts two arguments in Python: a function and an iterable such as a list.
# * The function is called for every item of the list, and a new iterable or list is returned that holds just those elements that returned True when supplied to the function.
#
# **Examples:**

# %%
li = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61]
final_list = list(filter(lambda x: (x % 2 != 0), li))
print(final_list)
# Out:
# [5, 7, 97, 77, 23, 73, 61]

# %%
list_ = [35, 12, 69, 55, 75, 14, 73]
odd_list = list(filter( lambda num: (num % 2 != 0) , list_ ))
print('The list of odd number is:',odd_list)
# Out:
# The list of odd number is: [35, 69, 55, 75, 73]

# %% [markdown]
# **Using lambda() Function with map():**
# * The map() function in Python takes in a function and a list as an argument.
# * The function is called with a lambda function and a list and a new list is returned which contains all the lambda-modified items returned by that function for each item.
#
# **Examples:**

# %%
li = [5, 7, 22, 97, 54, 62, 77, 23, 73, 61]
final_list = list(map(lambda x: x*2, li))
print(final_list)
# Out:
# [10, 14, 44, 194, 108, 124, 154, 46, 146, 122]

# %%
numbers_list = [2, 4, 5, 1, 3, 7, 8, 9, 10]
squared_list = list(map( lambda num: num ** 2 , numbers_list ))
print( 'Square of each number in the given list:' ,squared_list )
# Out:
# Square of each number in the given list: [4, 16, 25, 1, 9, 49, 64, 81, 100]

# %% [markdown]
# **Scope of the variables:**
# * All variables in a program may not be accessible at all locations in that program. This depends on where you have declared a variable.
# * The scope of a variable determines the portion of the program where you can access a particular identifier.
# * There are two basic scopes of variables in Python.They are:
#
#     1)Local variables
#
#     2)Global Variables

# %% [markdown]
# **1)Local variables:**
# * Local variables in Python are those which are initialized inside a function and belong only to that particular function.
# * It cannot be accessed anywhere outside the function.
#
# **Examples:**

# %%
def f():
    # local variable
    s = "I love my india"
    print(s)
# Driver code
f()
# Out:
# I love my india

# %%
def function_one():
    x = 117
    print(f"Function One: x = {x}")
def function_two():
    x = 89
    print(f"Function Two: x = {x}")
function_one()
function_two()
# Out:
# Function One: x = 117
# Function Two: x = 89

# %% [markdown]
# **2)Global Variables:**
# * These are those which are defined outside any function and which are accessible throughout the program, i.e., inside and outside of every function.
# * Global variables can be used by everyone, both inside of functions and outside.
#
# **Examples:**

# %%
# This function uses global variable s
def f():
    print("Inside Function", s)

# Global scope
s = "I love Nizamabad"
f()
print("Outside Function", s)
# Out:
# Inside Function I love Nizamabad
# Outside Function I love Nizamabad

# %%
def f():
    s = "Me too."
    print(s)

# Global scope
s = "I love nizamabad"
f()
print(s)
# Out:
# Me too.
# I love nizamabad
